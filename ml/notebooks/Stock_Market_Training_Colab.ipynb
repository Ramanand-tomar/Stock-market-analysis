# %% [markdown]
# # Stock Market Analysis - Cloud Training
#
# This notebook allows you to train your machine learning models on Google's cloud infrastructure.
#
# ### Instructions:
# 1.  **Upload the Zip**: Click on the 'Files' icon on the left and upload your `stock_analysis_colab.zip` file.
# 2.  **Run All**: Press `Ctrl + F9` to run all cells.
# 3.  **Download Results**: After training finishes, the models and metrics will be saved. You can download them back to your computer.

# %%
# 1. Unzip the project
# !unzip -o stock_analysis_colab.zip

# %%
# 2. Install dependencies
# !pip install -r requirements.txt

# %%
# 3. Set up environment
import sys
import os
sys.path.append(os.getcwd())

# %%
# 4. Run Training
# !python ml/train/run_training.py

# %%
# 5. Package results for download
# !zip -r training_results.zip ml/models metrics.json
